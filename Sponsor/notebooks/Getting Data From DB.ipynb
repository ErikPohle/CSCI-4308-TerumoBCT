# %%
import pyodbc
import pandas as pd
import gc

# %% [markdown]
# First establish connection with database.

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=10.183.135.105\SQLEXPRESS;DATABASE=RSM_DDB_DB;UID=cu_user_3;PWD=?X#/bjwVcfAw2J/c')
# Out:
# ErrorTraceback (most recent call last)
# <ipython-input-2-8e2b9c70f6ed> in <module>
# ----> 1 conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=10.183.135.105\SQLEXPRESS;DATABASE=RSM_DDB_DB;UID=cu_user_3;PWD=?X#/bjwVcfAw2J/c')
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'ODBC Driver 17 for SQL Server' : file not found (0) (SQLDriverConnect)")

# %% [markdown]
# Now fetch all tables and save local copies of them. Be patient this will take a while, potentially >30 minutes.
#
# You can expect total disk space usage to be ~5.5 GB

# %%
dim_blood_product = pd.DataFrame()
readFrame = pd.read_feather("../data/raw/dim_blood_product.feather")
readFrame.tail()
#del dim_blood_product
#gc.collect()
# Out:
#                    dim_blood_product_id    blood_product_type
# 2  97412C1A-1127-EB11-80C7-005056AF16E2         Plasma_Volume
# 3  98412C1A-1127-EB11-80C7-005056AF16E2       Platelet_Volume
# 4  99412C1A-1127-EB11-80C7-005056AF16E2  Platelet_Yield_Index
# 5  9A412C1A-1127-EB11-80C7-005056AF16E2  Rbc_Prefilter_Volume
# 6  9B412C1A-1127-EB11-80C7-005056AF16E2    Whole_Blood_Volume

# %%
dim_config = pd.DataFrame()
dim_config = pd.read_feather("../data/raw/dim_configuration.feather")
dim_config.tail()
# Out:
#                       dim_configuration_id  \
# 5742  A124989C-1127-EB11-80C7-005056AF16E2
# 5743  A224989C-1127-EB11-80C7-005056AF16E2
# 5744  A324989C-1127-EB11-80C7-005056AF16E2
# 5745  A424989C-1127-EB11-80C7-005056AF16E2
# 5746  A524989C-1127-EB11-80C7-005056AF16E2
#
#                  run_data_configuration_id  configuration_name  \
# 5742  4D258BC9-2740-45A4-950F-B1B7791A922C              US SUT
# 5743  CB1A4F91-F35A-4938-A2B9-6EC12735F0EF      rus smoke test
# 5744  B9D28A29-1986-421E-B1FA-BB4902B58CC5               NO_PT
# 5745  95844A15-2F78-4F0E-996B-F0894CE22AEA            GUI Show
# 5746  A733C350-E034-4B1C-83B6-FB01D12E00AE  New 3C Fresh Blood
#
#                        protocol_name                     protocol_adpt_name  \
# 5742                          US SUT             US SUT_2019_05_30_14_49_03
# 5743                   Rus Smoketest       Smoke Test 2_2014_10_29_15_08_39
# 5744  RV_2C_ON_Blood_V1_10_002_2015_    Blood_V1_10_002_2015_03_11_16_42_53
# 5745                        GUI only  ShowOffGUI3C_0501_2014_05_01_08_57_50
# 5746              New 3C Fresh Blood          V1_11_002_2017_08_01_12_23_23
#
#      configuration_status
# 5742              Service
# 5743              Service
# 5744              Routine
# 5745              Service
# 5746              Routine

# %%
dim_custom_data_01 = pd.DataFrame()
dim_custom_data_01 = pd.read_feather("../data/raw/dim_custom_data_01.feather")
dim_custom_data_01.tail()
# Out:
#                          run_data_donation_id  \
# 5283311  2960A7D9-AE1B-4001-BEE2-7E097A8F0095
# 5283312  6CD44FDF-693E-4497-B9E1-DACEC3748810
# 5283313  0C597B2E-4EBB-4FB6-8631-804D6824EEE1
# 5283314  C0511AF9-4FD9-4E0C-8F9E-3DC39F0327F7
# 5283315  A7A5DCA3-9D1D-4FD0-B071-08C8DC641281
#
#                            dim_custom_data_id data001 data002 data003 data004  \
# 5283311  71E30720-B567-4CC6-A28F-FFFFFC3BD20C       3       7    2600      28
# 5283312  3A5DDEAA-5C9A-48E5-BCA0-FFFFFD61D229       2       7    2900      30
# 5283313  6AD326BD-13AD-455B-BC8F-FFFFFE68941D       3     4.5    2600      28
# 5283314  AEBC2FC9-EBAF-46E0-9BB9-FFFFFF1F6BF0       3       7    2600      30
# 5283315  E3A5C5A2-AFB8-4292-9668-FFFFFFE22D8D       2       7    2900      30
#
#         data005 data006 data007 data008  ... data041 data042 data043 data044  \
# 5283311     500     500     500     500  ...     1.5      10     0.9     1.1
# 5283312     500     120     500     120  ...    0.75       5     0.9     1.1
# 5283313     300     120     300     120  ...     1.5      10     0.9     1.1
# 5283314     300     120     300     120  ...    0.75      10     0.9     1.1
# 5283315     500     120     500     120  ...    0.75       5     0.9     1.1
#
#         data045 data046 data047 data048 data049 data050
# 5283311     0.8     100       1       9      20      32
# 5283312     0.5     100       1       9      20      32
# 5283313     0.8     100       1       9      20      32
# 5283314     0.8     100    1.04       0      20      32
# 5283315     0.5     100       1       9      20      32
#
# [5 rows x 52 columns]

# %%
dim_custom_data_02 = pd.DataFrame()
dim_custom_data_02 = pd.read_feather("../data/raw/dim_custom_data_02.feather")
dim_custom_data_02.tail()
# Out:
#                          run_data_donation_id  \
# 4756195  DDA1AC39-1A06-48F2-90B7-FFFFF028B467
# 4756196  F9C1CCA3-4BF8-472E-90EF-FFFFF373C4B2
# 4756197  40CFF8FD-B757-415D-AC0A-FFFFFD1E73B6
# 4756198  3825B22E-9701-4A96-95AE-FFFFFD4424E9
# 4756199  DED723C8-D323-468E-A079-FFFFFEB23757
#
#                            dim_custom_data_id data051 data052 data053 data054  \
# 4756195  FC083B6A-92A6-476A-A80A-74BE0630C02E       0     100       1      10
# 4756196  79A547D5-A6E9-4927-89C2-B48955CCCE7F       0     100       1      13
# 4756197  B76639BB-DC78-4711-9955-76AD8A8CF80A       0     100       1      13
# 4756198  3A2D6336-AD48-495D-9346-309264760B34      50      58       1      13
# 4756199  D603C2E5-B910-4E9C-AF96-2B20BCD65FAB       0     100       1      10
#
#                   data055          data056           data057  \
# 4756195  18.5067138671875  15.448486328125  18.4566650390625
# 4756196                 0                0                 0
# 4756197                 0                0                 0
# 4756198                 0                0                 0
# 4756199  18.8612670898438                0      17.955078125
#
#                   data058  ... data091 data092 data093 data094 data095  \
# 4756195  16.7191162109375  ...       0       0       0       0    None
# 4756196                 0  ...       0       0       0       0    None
# 4756197                 0  ...       0       0       0       0    None
# 4756198                 0  ...    None    None    None    None    None
# 4756199                 0  ...       0       0       0       0    None
#
#         data096 data097 data098 data099 data100
# 4756195    None    None    None    None    None
# 4756196    None    None    None    None    None
# 4756197    None    None    None    None    None
# 4756198    None    None    None    None    None
# 4756199    None    None    None    None    None
#
# [5 rows x 52 columns]

# %%
dim_custom_data_03 = pd.DataFrame()
dim_custom_data_03 = pd.read_feather("../data/raw/dim_custom_data_03.feather")
dim_custom_data_03.tail()
# Out:
#                        run_data_donation_id  \
# 14903  0906F43B-02D2-4A8D-B050-FFF4EC3995E3
# 14904  E6421BD7-95F5-4715-8193-FFF72060246C
# 14905  A71A17A4-0FEC-41EF-906B-FFFA85085B75
# 14906  B3C70C36-09F6-4C5B-8E64-FFFC27FE0DE8
# 14907  BA4C1ED3-72F6-4BE2-BBDD-FFFE60508DDD
#
#                          dim_custom_data_id data101 data102 data103 data104  \
# 14903  3E8DD902-9379-481D-9BD3-319B1182568A     300     120     300     300
# 14904  4A59DB64-99D3-49C0-9357-F90AD8483D61     300     120     300     300
# 14905  57DC05CC-94EA-4774-BC29-9A90BC17C9E3     300     120     300     300
# 14906  00CDCAF8-AC69-42DC-886D-618AF70FA8F2     300     120     300     300
# 14907  6A715561-D049-4F47-BB55-9BAD1FA6F8FD     300     120     300     300
#
#       data105 data106 data107 data108  ... data141 data142 data143 data144  \
# 14903     120      66      30      10  ...      -6      -6       0    2600
# 14904     120      66      30      10  ...      -6      -6       0    2600
# 14905     120      66      30      10  ...      -6      -6       0    2600
# 14906     120      66      30      10  ...      -6      -6       0    2600
# 14907     120      66      30      10  ...      -6      -6       0    2600
#
#       data145 data146 data147 data148 data149 data150
# 14903    2900    1800       0    1800       0    1800
# 14904    2900    1000       1    2900     180    1800
# 14905    2900    1800       0    1800       0    1800
# 14906    2900    1800       0    1800       0    1800
# 14907    2900    1800       0    1800       0    1800
#
# [5 rows x 52 columns]

# %%
dim_custom_data_04 = pd.DataFrame()
dim_custom_data_04 = pd.read_feather("../data/raw/dim_custom_data_04.feather")
dim_custom_data_04.tail()
# Out:
#                        run_data_donation_id  \
# 14903  0906F43B-02D2-4A8D-B050-FFF4EC3995E3
# 14904  E6421BD7-95F5-4715-8193-FFF72060246C
# 14905  A71A17A4-0FEC-41EF-906B-FFFA85085B75
# 14906  B3C70C36-09F6-4C5B-8E64-FFFC27FE0DE8
# 14907  BA4C1ED3-72F6-4BE2-BBDD-FFFE60508DDD
#
#                          dim_custom_data_id data151 data152 data153 data154  \
# 14903  3E8DD902-9379-481D-9BD3-319B1182568A    1600       0       0   -3000
# 14904  4A59DB64-99D3-49C0-9357-F90AD8483D61    1600       0       0   -3000
# 14905  57DC05CC-94EA-4774-BC29-9A90BC17C9E3    1600       0       0   -3000
# 14906  00CDCAF8-AC69-42DC-886D-618AF70FA8F2    1600       0       0   -3000
# 14907  6A715561-D049-4F47-BB55-9BAD1FA6F8FD    1600       0       0   -3000
#
#       data155 data156 data157 data158  ... data190 data191 data192 data193  \
# 14903  100000     0.5      20      52  ...    None    None    None    None
# 14904  100000     0.5      20      52  ...    None    None    None    None
# 14905  100000     0.5      20      52  ...    None    None    None    None
# 14906  100000     0.5      20      52  ...    None    None    None    None
# 14907  100000     0.5      20      52  ...    None    None    None    None
#
#       data194 data195 data196 data197 data198 data199
# 14903    None    None    None    None    None    None
# 14904    None    None    None    None    None    None
# 14905    None    None    None    None    None    None
# 14906    None    None    None    None    None    None
# 14907    None    None    None    None    None    None
#
# [5 rows x 51 columns]

# %%
dim_run = pd.DataFrame()
dim_run = pd.read_feather("../data/raw/dim_run.feather")
dim_run.tail()
# Out:
#                                        run_id  \
# 1329730  BC742DA6-CF81-42D4-BE22-FFFEE0A996D1
# 1329731  C32352E6-8079-4C85-84EC-FFFE7A8E114C
# 1329732  2B5DAFC8-4193-408D-B918-FFFF80C7FA3D
# 1329733  79896079-F111-47AF-B638-FFF6D800EB07
# 1329734  781D563A-CDC7-47BC-ACF3-FFFC2FE1A8E1
#
#                                    dim_run_id  \
# 1329730  05F2018E-1127-EB11-80C7-005056AF16E2
# 1329731  06F2018E-1127-EB11-80C7-005056AF16E2
# 1329732  07F2018E-1127-EB11-80C7-005056AF16E2
# 1329733  08F2018E-1127-EB11-80C7-005056AF16E2
# 1329734  09F2018E-1127-EB11-80C7-005056AF16E2
#
#                                 file_name  run_number first_barcode_scantime  \
# 1329730  1W00248_20180714_001_007035.dlog        7035                   None
# 1329731  1W00210_20190327_009_008420.dlog        8420                   None
# 1329732  1W00193_20200813_000_012342.dlog       12342                   None
# 1329733  1W00115_20180623_005_023449.dlog       23449                   None
# 1329734  1W00123_20140722_004_004215.dlog        4215                   None
#
#         last_barcode_scantime barcode_skip_status          start_datetime  \
# 1329730                  None        None Skipped 2018-07-14 08:45:57.000
# 1329731                  None        None Skipped 2019-03-27 15:03:19.000
# 1329732                  None        None Skipped 2020-08-13 15:01:29.000
# 1329733                  None        None Skipped 2018-06-23 07:20:13.000
# 1329734                  None        None Skipped 2014-07-22 02:35:46.220
#
#         operator_id
# 1329730        None
# 1329731      121372
# 1329732      114713
# 1329733      00PMCA
# 1329734   A0008559A

# %%
dim_operator = pd.DataFrame()
dim_operator = pd.read_feather("../data/raw/dim_operator.feather")
dim_operator.tail()
# Out:
#                            dim_operator_id       operator_id
# 3240  B4B55BA5-1127-EB11-80C7-005056AF16E2              ZJJX
# 3241  41B55BA5-1127-EB11-80C7-005056AF16E2              ZJT2
# 3242  90B55BA5-1127-EB11-80C7-005056AF16E2  ZLLMRC93D25H282B
# 3243  A1B85BA5-1127-EB11-80C7-005056AF16E2          ZSunaydi
# 3244  97B75BA5-1127-EB11-80C7-005056AF16E2              ZY Z

# %%
dim_donation = pd.DataFrame()
dim_donation = pd.read_feather("../data/raw/dim_donation.feather")
dim_donation.tail()
# Out:
#                                   donation_id  \
# 5318935  F8C32E89-63D2-4493-8E6F-F7E17D97CE82
# 5318936  475D8A4B-80E5-456E-BB03-F7DB940F3C09
# 5318937  D41EBB84-64CF-47DF-B75E-FE3EB0FBED4F
# 5318938  DCD32C37-7503-4D63-8E04-FB05B10985F3
# 5318939  92963A3B-D817-488D-BD65-FE3E1EEFBA24
#
#                               dim_donation_id donation_status  bucket_number  \
# 5318935  BDFB1437-1127-EB11-80C7-005056AF16E2        Complete              3
# 5318936  BEFB1437-1127-EB11-80C7-005056AF16E2        Complete              1
# 5318937  BFFB1437-1127-EB11-80C7-005056AF16E2        Complete              3
# 5318938  C0FB1437-1127-EB11-80C7-005056AF16E2        Complete              4
# 5318939  C1FB1437-1127-EB11-80C7-005056AF16E2        Complete              2
#
#               unit_number unit_number_lifetime_status operator_id  \
# 5318935            500312                    Complete        None
# 5318936      160819003538                    Complete        0020
# 5318937          16093579                    Complete      48E506
# 5318938  =J00301901224901                    Complete      JULIBE
# 5318939     0124200626022                    Complete     1619543
#
#           welding_status        run_datetime
# 5318935  Weld Successful 2018-03-11 15:51:38
# 5318936  Weld Successful 2019-07-19 10:07:40
# 5318937  Weld Successful 2016-09-21 14:04:29
# 5318938  Weld Successful 2019-07-22 12:59:02
# 5318939  Weld Successful 2020-06-26 16:55:56

# %%
dim_exception = pd.DataFrame()
dim_exception = pd.read_feather("../data/raw/dim_exception.feather")
dim_exception.tail()
# Out:
#                    run_data_message_entry_id  \
# 599262  477B4F97-32D7-4807-83CB-B9710C3D04FA
# 599263  3F858B48-2582-4B59-9198-B978E9329996
# 599264  EAF8F123-A42A-4B06-A387-B978FB64FEE3
# 599265  79EA705D-653B-4C6C-9FD2-B96F63CE6250
# 599266  8CF5E5F7-59F9-42AC-841B-B97AF56E4E9F
#
#                             dim_exception_id alarm_id  bucket_number  \
# 599262  1816C26C-1127-EB11-80C7-005056AF16E2     1069            NaN
# 599263  1916C26C-1127-EB11-80C7-005056AF16E2     1016            NaN
# 599264  1A16C26C-1127-EB11-80C7-005056AF16E2     1016            NaN
# 599265  1B16C26C-1127-EB11-80C7-005056AF16E2     1064            4.0
# 599266  1C16C26C-1127-EB11-80C7-005056AF16E2     1069            NaN
#
#                                 message              time_stamp  \
# 599262              1069 Fuga detectada 2018-04-24 20:24:46.000
# 599263   1016 ID del operador no válida 2020-02-29 08:42:43.000
# 599264  1016 ID del operador no v??lida 2014-01-29 14:19:09.863
# 599265      1064 Tom behållare upptäckt 2018-08-10 06:11:02.000
# 599266               1069 Fuga detetada 2015-08-03 09:34:28.000
#
#        exception_type exception_state            run_datetime
# 599262          Alert         PostRun 2018-04-24 20:07:35.000
# 599263          Alert          PreRun 2020-02-29 08:44:31.000
# 599264          Alarm            None 2014-01-29 14:19:38.567
# 599265          Alert          PreRun 2018-08-10 06:11:24.000
# 599266          Alert         PostRun 2015-08-03 08:55:29.000

# %%
dim_facility = pd.DataFrame()
dim_facility = pd.read_feather("../data/raw/dim_facility.feather")
dim_facility.tail()
# Out:
#                           dim_facility_id                facility_name  \
# 348  2E0E989C-1127-EB11-80C7-005056AF16E2                  BCT EOT Lab
# 349  2F0E989C-1127-EB11-80C7-005056AF16E2             Demo Deutschland
# 350  300E989C-1127-EB11-80C7-005056AF16E2                         Jena
# 351  310E989C-1127-EB11-80C7-005056AF16E2                    Pizza Hut
# 352  320E989C-1127-EB11-80C7-005056AF16E2  Universitaetsklinikum Halle
#
#                                      facility_timezone
# 348  Mountain Standard Time;-420;(UTC-07:00) Mounta...
# 349  Pacific Standard Time;-480;(UTC-08:00) Pacific...
# 350  Romance Standard Time;60;(UTC+01:00) Brussels,...
# 351  Mountain Standard Time;-420;(UTC-07:00) Mounta...
# 352  E. Europe Standard Time;120;(UTC+02:00) E. Eur...

# %%
dim_operator = pd.DataFrame()
dim_operator = pd.read_feather("../data/raw/dim_operator.feather")
dim_operator.tail()
# Out:
#                            dim_operator_id       operator_id
# 3240  B4B55BA5-1127-EB11-80C7-005056AF16E2              ZJJX
# 3241  41B55BA5-1127-EB11-80C7-005056AF16E2              ZJT2
# 3242  90B55BA5-1127-EB11-80C7-005056AF16E2  ZLLMRC93D25H282B
# 3243  A1B85BA5-1127-EB11-80C7-005056AF16E2          ZSunaydi
# 3244  97B75BA5-1127-EB11-80C7-005056AF16E2              ZY Z

# %%
dim_run = pd.DataFrame()
dim_run = pd.read_feather("../data/raw/dim_run.feather")
dim_run.tail()
# Out:
#                                        run_id  \
# 1329730  BC742DA6-CF81-42D4-BE22-FFFEE0A996D1
# 1329731  C32352E6-8079-4C85-84EC-FFFE7A8E114C
# 1329732  2B5DAFC8-4193-408D-B918-FFFF80C7FA3D
# 1329733  79896079-F111-47AF-B638-FFF6D800EB07
# 1329734  781D563A-CDC7-47BC-ACF3-FFFC2FE1A8E1
#
#                                    dim_run_id  \
# 1329730  05F2018E-1127-EB11-80C7-005056AF16E2
# 1329731  06F2018E-1127-EB11-80C7-005056AF16E2
# 1329732  07F2018E-1127-EB11-80C7-005056AF16E2
# 1329733  08F2018E-1127-EB11-80C7-005056AF16E2
# 1329734  09F2018E-1127-EB11-80C7-005056AF16E2
#
#                                 file_name  run_number first_barcode_scantime  \
# 1329730  1W00248_20180714_001_007035.dlog        7035                   None
# 1329731  1W00210_20190327_009_008420.dlog        8420                   None
# 1329732  1W00193_20200813_000_012342.dlog       12342                   None
# 1329733  1W00115_20180623_005_023449.dlog       23449                   None
# 1329734  1W00123_20140722_004_004215.dlog        4215                   None
#
#         last_barcode_scantime barcode_skip_status          start_datetime  \
# 1329730                  None        None Skipped 2018-07-14 08:45:57.000
# 1329731                  None        None Skipped 2019-03-27 15:03:19.000
# 1329732                  None        None Skipped 2020-08-13 15:01:29.000
# 1329733                  None        None Skipped 2018-06-23 07:20:13.000
# 1329734                  None        None Skipped 2014-07-22 02:35:46.220
#
#         operator_id
# 1329730        None
# 1329731      121372
# 1329732      114713
# 1329733      00PMCA
# 1329734   A0008559A

# %%
fact_blood_product = pd.DataFrame()
fact_blood_product = pd.read_feather("../data/raw/fact_blood_product.feather")
fact_blood_product.tail()
# Out:
#          dim_run_date                         dim_device_id  \
# 17971043   2020-10-04  DD472C1A-1127-EB11-80C7-005056AF16E2
# 17971044   2020-10-04  DD472C1A-1127-EB11-80C7-005056AF16E2
# 17971045   2019-10-14  DD472C1A-1127-EB11-80C7-005056AF16E2
# 17971046   2019-10-14  DD472C1A-1127-EB11-80C7-005056AF16E2
# 17971047   2019-10-14  DD472C1A-1127-EB11-80C7-005056AF16E2
#
#                                dim_donation_id dim_custom_data_id  \
# 17971043  AFE93B36-1127-EB11-80C7-005056AF16E2               None
# 17971044  AFE93B36-1127-EB11-80C7-005056AF16E2               None
# 17971045  3B41EB2F-1127-EB11-80C7-005056AF16E2               None
# 17971046  3B41EB2F-1127-EB11-80C7-005056AF16E2               None
# 17971047  3B41EB2F-1127-EB11-80C7-005056AF16E2               None
#
#                                     dim_run_id  \
# 17971043  46B35D8A-1127-EB11-80C7-005056AF16E2
# 17971044  46B35D8A-1127-EB11-80C7-005056AF16E2
# 17971045  8C6EDE8A-1127-EB11-80C7-005056AF16E2
# 17971046  8C6EDE8A-1127-EB11-80C7-005056AF16E2
# 17971047  8C6EDE8A-1127-EB11-80C7-005056AF16E2
#
#                                dim_facility_id  \
# 17971043  240D989C-1127-EB11-80C7-005056AF16E2
# 17971044  240D989C-1127-EB11-80C7-005056AF16E2
# 17971045  240D989C-1127-EB11-80C7-005056AF16E2
# 17971046  240D989C-1127-EB11-80C7-005056AF16E2
# 17971047  240D989C-1127-EB11-80C7-005056AF16E2
#
#                           dim_configuration_id dim_operator_id  \
# 17971043  E416989C-1127-EB11-80C7-005056AF16E2            None
# 17971044  E416989C-1127-EB11-80C7-005056AF16E2            None
# 17971045  E416989C-1127-EB11-80C7-005056AF16E2            None
# 17971046  E416989C-1127-EB11-80C7-005056AF16E2            None
# 17971047  E416989C-1127-EB11-80C7-005056AF16E2            None
#
#                           dim_blood_product_id  product_volume  \
# 17971043  99412C1A-1127-EB11-80C7-005056AF16E2              75
# 17971044  96412C1A-1127-EB11-80C7-005056AF16E2              13
# 17971045  96412C1A-1127-EB11-80C7-005056AF16E2              10
# 17971046  97412C1A-1127-EB11-80C7-005056AF16E2             216
# 17971047  98412C1A-1127-EB11-80C7-005056AF16E2              55
#
#           number_of_units_processed
# 17971043                          1
# 17971044                          1
# 17971045                          1
# 17971046                          1
# 17971047                          1

# %%
fact_donation = pd.DataFrame()
fact_donation = pd.read_feather("../data/raw/fact_donation.feather")
fact_donation.tail()
# Out:
#         dim_run_date                         dim_device_id  \
# 5318935   2020-11-10  A0492C1A-1127-EB11-80C7-005056AF16E2
# 5318936   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 5318937   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 5318938   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 5318939   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
#
#                               dim_donation_id  \
# 5318935  F0617036-1127-EB11-80C7-005056AF16E2
# 5318936  BD541435-1127-EB11-80C7-005056AF16E2
# 5318937  D62DA835-1127-EB11-80C7-005056AF16E2
# 5318938  1DF04733-1127-EB11-80C7-005056AF16E2
# 5318939  1FF22034-1127-EB11-80C7-005056AF16E2
#
#                            dim_custom_data_id  \
# 5318935  6273B065-AF87-411B-8559-0DC00D3C39AC
# 5318936                                  None
# 5318937                                  None
# 5318938                                  None
# 5318939                                  None
#
#                                    dim_run_id  \
# 5318935  DA967784-1127-EB11-80C7-005056AF16E2
# 5318936  641B9A87-1127-EB11-80C7-005056AF16E2
# 5318937  641B9A87-1127-EB11-80C7-005056AF16E2
# 5318938  641B9A87-1127-EB11-80C7-005056AF16E2
# 5318939  641B9A87-1127-EB11-80C7-005056AF16E2
#
#                               dim_facility_id  \
# 5318935  860D989C-1127-EB11-80C7-005056AF16E2
# 5318936  860D989C-1127-EB11-80C7-005056AF16E2
# 5318937  860D989C-1127-EB11-80C7-005056AF16E2
# 5318938  860D989C-1127-EB11-80C7-005056AF16E2
# 5318939  860D989C-1127-EB11-80C7-005056AF16E2
#
#                          dim_configuration_id  \
# 5318935  D71A989C-1127-EB11-80C7-005056AF16E2
# 5318936  C322989C-1127-EB11-80C7-005056AF16E2
# 5318937  C322989C-1127-EB11-80C7-005056AF16E2
# 5318938  C322989C-1127-EB11-80C7-005056AF16E2
# 5318939  C322989C-1127-EB11-80C7-005056AF16E2
#
#                               dim_operator_id  number_of_units_processed  \
# 5318935  FAAC5BA5-1127-EB11-80C7-005056AF16E2                          1
# 5318936                                  None                          1
# 5318937                                  None                          1
# 5318938                                  None                          1
# 5318939                                  None                          1
#
#          number_of_duplicated_units  number_of_skipped_barcodes  \
# 5318935                           1                           0
# 5318936                           0                           0
# 5318937                           0                           0
# 5318938                           0                           0
# 5318939                           0                           0
#
#          number_of_alarms  number_of_alerts
# 5318935                 0                 0
# 5318936                 0                 1
# 5318937                 0                 1
# 5318938                 0                 1
# 5318939                 0                 1

# %%
fact_exception = pd.DataFrame()
fact_exception = pd.read_feather("../data/raw/fact_exception.feather")
fact_exception.tail()
# Out:
#        dim_run_date                         dim_device_id  \
# 599262   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 599263   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 599264   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 599265   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
# 599266   2013-10-24  A1492C1A-1127-EB11-80C7-005056AF16E2
#
#                                   dim_run_id  \
# 599262  641B9A87-1127-EB11-80C7-005056AF16E2
# 599263  641B9A87-1127-EB11-80C7-005056AF16E2
# 599264  641B9A87-1127-EB11-80C7-005056AF16E2
# 599265  641B9A87-1127-EB11-80C7-005056AF16E2
# 599266  641B9A87-1127-EB11-80C7-005056AF16E2
#
#                              dim_facility_id  \
# 599262  860D989C-1127-EB11-80C7-005056AF16E2
# 599263  860D989C-1127-EB11-80C7-005056AF16E2
# 599264  860D989C-1127-EB11-80C7-005056AF16E2
# 599265  860D989C-1127-EB11-80C7-005056AF16E2
# 599266  860D989C-1127-EB11-80C7-005056AF16E2
#
#                         dim_configuration_id dim_operator_id  \
# 599262  C322989C-1127-EB11-80C7-005056AF16E2            None
# 599263  C322989C-1127-EB11-80C7-005056AF16E2            None
# 599264  C322989C-1127-EB11-80C7-005056AF16E2            None
# 599265  C322989C-1127-EB11-80C7-005056AF16E2            None
# 599266  C322989C-1127-EB11-80C7-005056AF16E2            None
#
#                             dim_exception_id  number_of_duplicated_units  \
# 599262  FF82566C-1127-EB11-80C7-005056AF16E2                           0
# 599263  C5B2946C-1127-EB11-80C7-005056AF16E2                           0
# 599264  3CF1836C-1127-EB11-80C7-005056AF16E2                           0
# 599265  48DCAE6C-1127-EB11-80C7-005056AF16E2                           0
# 599266  FF22B16C-1127-EB11-80C7-005056AF16E2                           0
#
#         number_of_reprocessed_units  number_of_inconclusive_sealed_units  \
# 599262                            0                                    0
# 599263                            0                                    0
# 599264                            0                                    0
# 599265                            0                                    0
# 599266                            0                                    0
#
#         number_of_unrecognized_barcodes  number_of_skipped_barcodes  \
# 599262                                0                           0
# 599263                                0                           0
# 599264                                0                           0
# 599265                                0                           0
# 599266                                0                           0
#
#         number_of_temp_out_of_range_exceptions  number_of_alarms
# 599262                                       0                 1
# 599263                                       0                 1
# 599264                                       0                 1
# 599265                                       0                 1
# 599266                                       0                 1

# %%
fact_run = pd.DataFrame()
fact_run = pd.read_feather("../data/raw/fact_run.feather")
fact_run.tail()
# Out:
#         dim_run_date                         dim_device_id  \
# 1329730   2018-07-14  E5452C1A-1127-EB11-80C7-005056AF16E2
# 1329731   2019-03-27  88492C1A-1127-EB11-80C7-005056AF16E2
# 1329732   2020-08-13  BE462C1A-1127-EB11-80C7-005056AF16E2
# 1329733   2018-06-23  FF442C1A-1127-EB11-80C7-005056AF16E2
# 1329734   2014-07-22  A5482C1A-1127-EB11-80C7-005056AF16E2
#
#                                    dim_run_id  \
# 1329730  05F2018E-1127-EB11-80C7-005056AF16E2
# 1329731  06F2018E-1127-EB11-80C7-005056AF16E2
# 1329732  07F2018E-1127-EB11-80C7-005056AF16E2
# 1329733  08F2018E-1127-EB11-80C7-005056AF16E2
# 1329734  09F2018E-1127-EB11-80C7-005056AF16E2
#
#                               dim_facility_id  \
# 1329730  240D989C-1127-EB11-80C7-005056AF16E2
# 1329731  080E989C-1127-EB11-80C7-005056AF16E2
# 1329732  DD0C989C-1127-EB11-80C7-005056AF16E2
# 1329733  280D989C-1127-EB11-80C7-005056AF16E2
# 1329734  860D989C-1127-EB11-80C7-005056AF16E2
#
#                          dim_configuration_id  \
# 1329730  4B22989C-1127-EB11-80C7-005056AF16E2
# 1329731  F30F989C-1127-EB11-80C7-005056AF16E2
# 1329732  471E989C-1127-EB11-80C7-005056AF16E2
# 1329733  0419989C-1127-EB11-80C7-005056AF16E2
# 1329734  4F12989C-1127-EB11-80C7-005056AF16E2
#
#                               dim_operator_id  procedure_duration_minutes  \
# 1329730                                  None                   49.850000
# 1329731  9FB25BA5-1127-EB11-80C7-005056AF16E2                   30.816667
# 1329732  8FB05BA5-1127-EB11-80C7-005056AF16E2                   37.783333
# 1329733  7AAC5BA5-1127-EB11-80C7-005056AF16E2                   31.150000
# 1329734  A9B15BA5-1127-EB11-80C7-005056AF16E2                    0.000000
#
#          idle_time_duration_minutes  load_duration_minutes  \
# 1329730                   22.683333               2.516667
# 1329731                    0.683333               4.016667
# 1329732                    0.133333               4.600000
# 1329733                    4.083333               3.833333
# 1329734                    0.000000               0.000000
#
#          unload_duration_minutes  ...  run_duration_minutes  \
# 1329730                 1.116667  ...             20.033333
# 1329731                 0.883333  ...             21.633333
# 1329732                 1.250000  ...             21.950000
# 1329733                 0.150000  ...             20.133333
# 1329734                 0.000000  ...             18.418867
#
#          barcode_scan_duration_minutes  number_of_procedures  \
# 1329730                       1.633333                     1
# 1329731                       2.333333                     1
# 1329732                       2.950000                     1
# 1329733                       2.116667                     1
# 1329734                       1.483233                     1
#
#          number_of_dummy_bags  number_of_barcode_scans  \
# 1329730                     1                        4
# 1329731                     0                       11
# 1329732                     0                        9
# 1329733                     0                        9
# 1329734                     0                        9
#
#          number_of_barcodes_skipped  start_basin_temperature  \
# 1329730                           0                   21.557
# 1329731                           0                   21.301
# 1329732                           0                   21.919
# 1329733                           0                   22.210
# 1329734                           0                   21.870
#
#          end_basin_temperature  max_basin_temperature  min_basin_temperature
# 1329730                 21.520                 22.683                 21.160
# 1329731                 21.632                 22.597                 20.904
# 1329732                 20.544                 22.553                 20.541
# 1329733                 22.117                 23.164                 21.299
# 1329734                 22.067                 22.824                 21.076
#
# [5 rows x 21 columns]
